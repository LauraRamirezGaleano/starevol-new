# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
data_p1 = pd.read_csv('m1.00_giw_original_28_0024960.p1',skiprows=1, header = None, sep= '\s+') 
data_p3 = pd.read_csv('m1.00_giw_original_28_0024960.p3',skiprows=1, header = None, sep= '\s+') 
# data_p10 = pd.read_csv('test_igws_on_0001062.p10',skiprows=2, header = None, sep= '\s+') 

# data_p1_15 = pd.read_csv('test_igws_on_0002462.p1',skiprows=2, header = None, sep= '\s+') 
# data_p10_15 = pd.read_csv('test_igws_on_0002462.p10',skiprows=2, header = None, sep= '\s+')

# %%
# Assuming 'df' is your DataFrame
column_names_p1 = ["nsh", "yzi", "r", "T", "Rho", "P", "beta", "eta", "lnf", 
                "s", "Lr", "u", "xmr", "accel", "vr"]
# column_names_p10 = ["nsh", "omega", "Ucirc", "Dshear", "Dcirc", "Dtot", "Dh", "psi", "xlambda", 
#                 "abmuj", "Nuturb", "Numol", "Kt", "aux", "SB", 'STh', 'SNG', 'SNS','Sadv', 'STh1', 'STh2', 'SB1', 'SB2', 'SB3', 'SB4', 'vomega' ]

column_names_p3 = ['nsh', 'VmicroHe', 'VmicroHeTP', 'VmicroC12', 'VmicroC12TP',
                   'VmicroC13', 'VmicroC13TP', 'VmicroN14', 'VmicroN14TP',
                   'VmicroN15', 'VmicroN15TP', 'VmicroO16', 'VmicroO16TP',
                   'VmicroO17', 'VmicroO17TP', 'VmicroO18', 'VmicroO18TP',
                   'VmicroNe', 'VmicroNeTP', 'VmicroNa', 'VmicroNaTP',
                   'tconv', 'Vconv', 'rfconv', 'rfrad', 'enucl', 
                   'enupla', 'egrav', 'enunucl', 'Dconv', 
                   'dturb', 'Dherw', 'Dsc', 'Dthc', 
                   'Dondes', 'Dondeschim', 'Dturbulence', 
                   'Dbar', 'Dkyle', 'Dtacho', 'scz', 'Ro'] 
# nsh  VmicroHe    VmicroHeTP  VmicroC12   VmicroC12TP VmicroC13   VmicroC13TP VmicroN14   VmicroN14TP VmicroN15   VmicroN15TP VmicroO16   VmicroO16TP VmicroO17   VmicroO17TP VmicroO18   VmicroO18TP VmicroNe    VmicroNeTP  VmicroNa    VmicroNaTP tconv      Vconv         rfconv       rfrad      enucl       enupla       egrav     enunucl      Dconv       dturb      Dherw        Dsc         Dthc        Dondes      Dondeschim  Dturbulence      Dbar      Dkyle      Dtacho   scz   Ro


# Assign column names
data_p3.columns = column_names_p3
data_p1.columns = column_names_p1
# data_p10.columns = column_names_p10

# data_p1_15.columns = column_names_p1
# data_p10_15.columns = column_names_p10

# %%
plt.plot(data_p1['r'], data_p3['Ro'], label = '12')
#plt.plot(data_p3['r'], data_p3['omega'], label = '15')
plt.xlabel('Radius')
plt.ylabel('Rossby Number')
plt.yscale('log')
plt.ylim(1e-6,1e2)
plt.legend()
plt.show()

# %%
plt.plot(data_p1['r'], data_p10['omega'], label = '12')
plt.plot(data_p1_15['r'], data_p10_15['omega'], label = '15')
plt.xlabel('Radius')
plt.ylabel('Omega')
plt.yscale('log')
plt.legend()
plt.show()
